# %% [markdown]
# # **U-Net 모델 구현**
#
# ✅ 아래 코드는 PyTorch로 작성한 간단한 U-Net 모델입니다.
#
# ✅ 주요 목표: 작은 이미지 세트로 segmentation 학습을 테스트하기!
#
# ✅ 특징: 업샘플링(deconv/upsample 선택 가능), 입력 스케일링, Gaussian noise 추가, 배치 정규화 적용

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# --- 작은 U-Net 정의 ---
class UNetSmall(nn.Module):
    def __init__(self, upsample_mode='deconv', net_scaling=None, edge_crop=0, gaussian_noise_std=0.1):
        super().__init__()
        self.net_scaling = net_scaling
        self.edge_crop = edge_crop
        self.gaussian_noise_std = gaussian_noise_std
        self.upsample_mode = upsample_mode

         # Convolution Block: Conv -> ReLU -> Conv -> ReLU
        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True)
            )

        # 인코더 부분 목표 -> 128 까지!
        self.enc1 = conv_block(3, 16)
        self.enc2 = conv_block(16, 32)
        self.enc3 = conv_block(32, 64)
        self.enc4 = conv_block(64, 128)
        # Bottleneck
        self.center = conv_block(128, 128)
        self.pool = nn.MaxPool2d(1)


        # 업샘플링 부분 정의 (deconv 또는 upsample+conv) 로
        if upsample_mode == 'deconv':
            def upsample_layer(in_c, out_c):
                return nn.ConvTranspose2d(in_c, out_c, 1)
        else:
            def upsample_layer(in_c, out_c):
                return nn.Sequential(
                    nn.Upsample(scale_factor=2, mode='nearest'),
                    nn.Conv2d(in_c, out_c, 1)
                )
        # 디코더 부분
        self.up4 = upsample_layer(128, 128)
        self.dec4 = conv_block(128+128, 128)
        self.up3 = upsample_layer(128, 64)
        self.dec3 = conv_block(64+64, 64)
        self.up2 = upsample_layer(64, 32)
        self.dec2 = conv_block(32+32, 32)
        self.up1 = upsample_layer(32, 16)
        self.dec1 = conv_block(16+16, 16)

        # 최종 출력: 1채널(segmentation mask)
        self.final = nn.Conv2d(16,1,1)

    def forward(self, x):
        if self.net_scaling:
        # 입력 스케일링
            x = F.avg_pool2d(x, self.net_scaling)
        # Gaussian noise 추가
        if self.gaussian_noise_std:
            noise = torch.randn_like(x) * self.gaussian_noise_std
            x = x + noise

        # 배치 정규화 적용
        x = F.batch_norm(x, running_mean=None, running_var=None, training=True)

        # 인코더
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        # Bottleneck
        center = self.center(e4)

        # 디코더 + Skip Connection
        d4 = self.up4(center)
        d4 = torch.cat([d4,e4], dim=1)
        d4 = self.dec4(d4)

        d3 = self.up3(d4)
        d3 = torch.cat([d3,e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat([d2,e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat([d1,e1], dim=1)
        d1 = self.dec1(d1)

        out = self.final(d1)
        out = torch.sigmoid(out)
         # Crop + Pad
        if self.edge_crop > 0:
            out = out[:, :, self.edge_crop:-self.edge_crop, self.edge_crop:-self.edge_crop]
            out = F.pad(out, (self.edge_crop, self.edge_crop, self.edge_crop, self.edge_crop))
        # Upsample 다시 확대
        if self.net_scaling:
            out = F.interpolate(out, scale_factor=self.net_scaling, mode='nearest')

        return out

# %% [markdown]
# ## **학습용 데이터 생성하기**

# %%
batch_size = 32
x = torch.randn(batch_size, 3, 128, 128)  # RGB 이미지
y = (torch.rand(batch_size, 1, 128, 128) > 0.5).float()  # 랜덤 이진 마스크

dataset = TensorDataset(x, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# ## **데이터 시각화**

# %%
import matplotlib.pyplot as plt
# 첫 번째 이미지를 시각화
sample_x = x[0]
sample_y = y[0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_x.permute(1, 2, 0).numpy())
plt.title('Input Image')

plt.subplot(1, 2, 2)
plt.imshow(sample_y.squeeze().numpy(), cmap='gray')
plt.title('Ground Truth Mask')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.6217213..3.8560102].

# %% [markdown]
# ## **모델 선언 및 학습**

# %%
# --- 모델 선언 및 학습 ---
model = UNetSmall(upsample_mode='deconv', net_scaling=None, edge_crop=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

# 간단히 30 epoch만
for epoch in range(10):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss/len(loader):.4f}")
# Out:
# Epoch 1, Loss: 0.6942
# Epoch 2, Loss: 0.6932
# Epoch 3, Loss: 0.6932
# Epoch 4, Loss: 0.6931
# Epoch 5, Loss: 0.6931
# Epoch 6, Loss: 0.6931
# Epoch 7, Loss: 0.6931
# Epoch 8, Loss: 0.6931
# Epoch 9, Loss: 0.6930
# Epoch 10, Loss: 0.6930

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## **아래 주석을 풀고 U-Net 모델에 대해 간단히 설명해주세요 😀**
#
# - U-Net : 이미지의 픽셀 단위 분할(Segmentation) 을 위한 합성곱 신경망(CNN) 구조
# - 인코더 (Encoder)
#   - 이미지를 점점 축소하면서 특징(Feature) 을 추출합니다.
#   - 여러 층의 Conv -> ReLU -> MaxPool 로 구성됩니다.
#   - 결과적으로 “무엇이 있는가” 를 잘 인식합니다. (하지만 “어디에 있는가”는 잃게 됩니다.)
#
# - 디코더 (Decoder)
#   - 반대로 이미지를 확대(Upsample) 하면서 세밀한 공간 정보를 복원합니다.
#   - 인코더의 출력과 같은 크기로 복원하기 위해 ConvTranspose(Deconv) 또는 Upsample 사용.
#   - “어디에 있는가” 를 다시 복원합니다.
#
# - Skip Connection (스킵 연결)
#   - 인코더의 중간 feature를 디코더 단계로 직접 연결(concat) 합니다.
#   - 이렇게 하면 세밀한 위치 정보를 잃지 않고 유지할 수 있습니다.

# %% [markdown]
# [답변]
#
#
# ---

# %% [markdown]
# ## **아래 주석을 풀고 DeepLabv1, v2, v3. v3+  모델에 대해 각각 간단히 설명해주세요 🐶**

# %% [markdown]
# [답변]
#
# - U-Net과 비슷하게 DeepLab 계열도 이미지 분할(Semantic Segmentation) 모델이지만, 훨씬 깊은 CNN 기반(ResNet, Xception 등) 과 공간 정보를 유지하는 특수 기술을 사용합니다.
#
# [DeepLab v1]
#   - 기존 CNN의 다운샘플링으로 인한 해상도 손실 문제를 해결하기 위해 Atrous Convolution 을 시작
#   - 필터 사이에 구멍을 넣어 수용 영역 을 넓히면서도 특징맵 크기 를 유지한다.
#   - 물체 경계가 뭉개지고, 결과가 흐릿함.
#
# [DeepLab v2]
#   - 하나의 고정된 dilation rate로는 다양한 크기의 객체를 보기 어려움
#   - 그래서 여러 dilation rate를 동시에 적용 -> 다양한 크기 의 특징을 한 번에 캡처
#   - 멀리 있는 픽셀 관계까지 보는 여러 개의 Atrous Conv 병렬 구조
#
# [DeepLab v3]
#   - v2의 ASPP를 개선하여 Batch Normalization + 더 깊은 구조로 향상
#   - 추가로 Global Average Pooling을 ASPP에 포함시켜 전체 문맥 정보까지 함께 고려
#   - Fully Connected CRF(후처리)는 제거하고, 네트워크 내부에서 자체적으로 정교한 경계 처리.
#
# [DeepLab v3+]
#   - DeepLab v3를 Encoder-Decoder 형태로 확장.
#   - Encoder: ASPP + Deep CNN
#   - Decoder: 낮은 단계의 feature를 가져와 세밀한 경계 복원
#   - 결과적으로 정확한 경계 + 넓은 문맥 이해 둘 다 가능해짐
